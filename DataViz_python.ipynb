# %% [markdown]
# <a href="https://colab.research.google.com/github/Mafaz03/b/blob/main/DataViz_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
print(df.head())

print(df.describe())

print(df.isnull().sum())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
plt.scatter(df.sepal_length, df.sepal_width)
plt.xlabel("Sepal Length")
plt.xlabel("Sepal Width")
plt.title("Sepal Length vs Sepal Width")
plt.show()

# %%
plt.hist(df['petal_length'], bins=30, edgecolor='black')
plt.title('Distribution of Petal Length')
plt.xlabel('Petal Length')
plt.ylabel('Frequency')
plt.show()

# %%
species_counts = df['species'].value_counts()
plt.bar(species_counts.index, species_counts.values)
plt.title('Count of Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %%
plt.plot(df.petal_width, df.sepal_width)
plt.xlabel("Petal Length")
plt.xlabel("Sepal Width")
plt.title("Sepal Length vs Sepal Width")
plt.show()

# %%
plt.plot(df.petal_width, df.sepal_width)
plt.xlabel("Petal Length")
plt.xlabel("Sepal Width")
plt.title("Sepal Length vs Sepal Width")
plt.show()

# %%
species_counts = df['species'].value_counts()
plt.pie(species_counts, labels = species_counts.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x793e04a89d50>,
#   <matplotlib.patches.Wedge at 0x793e04a89c30>,
#   <matplotlib.patches.Wedge at 0x793e04a8a620>],
#  [Text(0.5499999702695115, 0.9526279613277875, 'setosa'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'versicolor'),
#   Text(0.5500001486524352, -0.9526278583383436, 'virginica')])

# %%
plt.boxplot(x = df.petal_width)
plt.title("Petal Width")
plt.show()

# %%
sns.heatmap(df.iloc[:,:-1])
# Out:
# <Axes: >
